# %%
import xml.etree.ElementTree as ET

# %%
a=ET.Element('mxfile')
a.set('type','device')
a.set('etag','d2m_BCRs5NTD1uJDUOON')
a.set('version','13.9.1')
a.set('agent','5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.75 Safari/537.36')
a.set('modified','2020-11-05T11:56:57.085Z')
a.set('host','app.diagrams.net')

# %%
b = ET.SubElement(a, 'diagram')
b.set('id','E2t0QyFFZp_JITEdpmB3')

# %%
c = ET.SubElement(b, 'mxGraphModel')
c.set('shadow','0')
c.set('math','0')
c.set('pageHeight','1169')
c.set('pageWidth','827')
c.set('pageScale','1')
c.set('page','1')
c.set('fold','1')
c.set('arrows','1')
c.set('connect','1')
c.set('tooltips','1')
c.set('guides','1')
c.set('gridSize','10')
c.set('grid','1')
c.set('dy','18481')
c.set('dx','21749')

# %%
d = ET.SubElement(c, 'root')

# %%
e = ET.SubElement(d, 'mxCell')
e.set('id','0')
f = ET.SubElement(d, 'mxCell')
f.set('id','1')
f.set('parent','0')

#Caja con clase Ordenador
g = ET.SubElement(d, 'mxCell')
g.set('id','2')
g.set('parent','1')
g.set('style','rounded=0;whiteSpace=wrap;html=1;fillColor=#fff2cc;strokeColor=#d6b656')
g.set('vertex','1')
g.set('value','Ordenador (Q68)')
g1 = ET.SubElement(g, 'mxGeometry')
g1.set('as','geometry')
g1.set('y','-16200')
g1.set('x','-18500')
g1.set('height','27')
g1.set('width','212')

#Caja con clase Pais
i = ET.SubElement(d, 'mxCell')
i.set('id','3')
i.set('parent','1')
i.set('style','rounded=0;whiteSpace=wrap;html=1')
i.set('vertex','1')
i.set('value','Pais (Q6250)')
i1 = ET.SubElement(i, 'mxGeometry')
i1.set('as','geometry')
i1.set('y','-16800')
i1.set('x','-18800')
i1.set('height','27')
i1.set('width','212')

#Flecha Pais de Origen
k = ET.SubElement(d, 'mxCell')
k.set('id','4')
k.set('parent','1')
k.set('target','3')
k.set('source','2')
k.set('edge','1')
k.set('style','edgeStyle=orthogonalEdgeStyle;rounded=0;orthogonalLoop=1;jettySize=auto;html=1;exitX=1;exitY=0.5;exitDx=0;exitDy=0;dashed=1;endArrow=classic;endFill=1;')
k.set('value','Pais de Origen (P495)')
k1 = ET.SubElement(k, 'mxGeometry')
k1.set('as','geometry')
k1.set('relative','1')

#Caja con clase Marca Registrada
l = ET.SubElement(d, 'mxCell')
l.set('id','5')
l.set('parent','1')
l.set('style','rounded=0;whiteSpace=wrap;html=1')
l.set('vertex','1')
l.set('value','Marca registrada (Q167270)')
l1 = ET.SubElement(l, 'mxGeometry')
l1.set('as','geometry')
l1.set('y','-16320')
l1.set('x','-19200')
l1.set('height','27')
l1.set('width','212')

#Flecha Marca
k = ET.SubElement(d, 'mxCell')
k.set('id','6')
k.set('parent','1')
k.set('target','5')
k.set('source','2')
k.set('edge','1')
k.set('style','edgeStyle=orthogonalEdgeStyle;rounded=0;orthogonalLoop=1;jettySize=auto;html=1;exitX=1;exitY=0.5;exitDx=0;exitDy=0;dashed=1;endArrow=classic;endFill=1;')
k.set('value','Marca (P1716)')
k1 = ET.SubElement(k, 'mxGeometry')
k1.set('as','geometry')
k1.set('relative','1')

#Caja con clase Lenguaje de programacion
l = ET.SubElement(d, 'mxCell')
l.set('id','7')
l.set('parent','1')
l.set('style','rounded=0;whiteSpace=wrap;html=1')
l.set('vertex','1')
l.set('value','Lenguaje de programacion (Q9143)')
l1 = ET.SubElement(l, 'mxGeometry')
l1.set('as','geometry')
l1.set('y','-16400')
l1.set('x','-19000')
l1.set('height','27')
l1.set('width','212')

#Flecha lenguaje de programacion
m = ET.SubElement(d, 'mxCell')
m.set('id','8')
m.set('parent','1')
m.set('target','7')
m.set('source','2')
m.set('edge','1')
m.set('style','edgeStyle=orthogonalEdgeStyle;rounded=0;orthogonalLoop=1;jettySize=auto;html=1;exitX=1;exitY=0.5;exitDx=0;exitDy=0;dashed=1;endArrow=classic;endFill=1;')
m.set('value','Lenguaje de programacion (P277)')
m1 = ET.SubElement(m, 'mxGeometry')
m1.set('as','geometry')
m1.set('relative','1')

#Caja con clase Pais
ac = ET.SubElement(d, 'mxCell')
ac.set('id','9')
ac.set('parent','1')
ac.set('style','rounded=0;whiteSpace=wrap;html=1')
ac.set('vertex','1')
ac.set('value','Pais (Q6256)')
ac1 = ET.SubElement(ac, 'mxGeometry')
ac1.set('as','geometry')
ac1.set('y','-17200')
ac1.set('x','-18800')
ac1.set('height','27')
ac1.set('width','212')

#Caja con clase Federacion
ad = ET.SubElement(d, 'mxCell')
ad.set('id','10')
ad.set('parent','1')
ad.set('style','rounded=0;whiteSpace=wrap;html=1')
ad.set('vertex','1')
ad.set('value','Federacion (Q43702)')
ad1 = ET.SubElement(ad, 'mxGeometry')
ad1.set('as','geometry')
ad1.set('y','-17200')
ad1.set('x','-18500')
ad1.set('height','27')
ad1.set('width','212')

#Simbolo de union
ak = ET.SubElement(d,'mxCell')
ak.set('id','11')
ak.set('parent','1')
ak.set('style','ellipse;whiteSpace=wrap;html=1;aspect=fixed;fontSize=17;')
ak.set('vertex','1')
ak.set('value','<span class="st">U</span>')
ak1=ET.SubElement(ak,'mxGeometry')
ak1.set('as','geometry')
ak1.set('y','-17100')
ak1.set('x','-18550')
ak1.set('height','30')
ak1.set('width','30')

#Flecha Pais
af = ET.SubElement(d, 'mxCell')
af.set('id','12')
af.set('parent','1')
af.set('target','9')
af.set('source','11')
af.set('edge','1')
af.set('style','edgeStyle=orthogonalEdgeStyle;rounded=0;orthogonalLoop=1;jettySize=auto;html=1;exitX=1;exitY=0.5;exitDx=0;exitDy=0;dashed=1;endArrow=classic;endFill=1;')
af1 = ET.SubElement(af, 'mxGeometry')
af1.set('as','geometry')
af1.set('relative','1')

#Flecha a simbolo de union
ag = ET.SubElement(d, 'mxCell')
ag.set('id','13')
ag.set('parent','1')
ag.set('target','11')
ag.set('source','2')
ag.set('edge','1')
ag.set('style','edgeStyle=orthogonalEdgeStyle;rounded=0;orthogonalLoop=1;jettySize=auto;html=1;exitX=1;exitY=0.5;exitDx=0;exitDy=0;dashed=1;endArrow=classic;endFill=1;')
ag.set('value','Pais (P17)')
ag1 = ET.SubElement(ag, 'mxGeometry')
ag1.set('as','geometry')
ag1.set('relative','1')

#Flecha a federacion
al = ET.SubElement(d, 'mxCell')
al.set('id','14')
al.set('parent','1')
al.set('target','10')
al.set('source','11')
al.set('edge','1')
al.set('style','edgeStyle=orthogonalEdgeStyle;rounded=0;orthogonalLoop=1;jettySize=auto;html=1;exitX=1;exitY=0.5;exitDx=0;exitDy=0;dashed=1;endArrow=classic;endFill=1;')
al1 = ET.SubElement(al, 'mxGeometry')
al1.set('as','geometry')
al1.set('relative','1')

#Caja con los dataType Strings
aj = ET.SubElement(d,'mxCell')
aj.set('id','15')
aj.set('parent','1')
aj.set('style','rounded=0;whiteSpace=wrap;html=1;align=left;dashed=1')
aj.set('vertex','1')
aj.set('value','Datatypes String')
aj1=ET.SubElement(aj,'mxGeometry')
aj1.set('as','geometry')
aj1.set('y','-16173')
aj1.set('x','-18500')
aj1.set('height','85')
aj1.set('width','212')

#Caja con clase Humano
ah = ET.SubElement(d, 'mxCell')
ah.set('id','16')
ah.set('parent','1')
ah.set('style','rounded=0;whiteSpace=wrap;html=1')
ah.set('vertex','1')
ah.set('value','Humano (Q5)')
ah1 = ET.SubElement(ah, 'mxGeometry')
ah1.set('as','geometry')
ah1.set('y','-15800')
ah1.set('x','-19050')
ah1.set('height','27')
ah1.set('width','212')

#Flecha con clase Humano
ai = ET.SubElement(d, 'mxCell')
ai.set('id','17')
ai.set('parent','1')
ai.set('target','16')
ai.set('source','2')
ai.set('edge','1')
ai.set('style','edgeStyle=orthogonalEdgeStyle;rounded=0;orthogonalLoop=1;jettySize=auto;html=1;exitX=1;exitY=0.5;exitDx=0;exitDy=0;dashed=1;endArrow=classic;endFill=1;')
ai.set('value','Diseñado por (P287)')
ai1 = ET.SubElement(ai, 'mxGeometry')
ai1.set('as','geometry')
ai1.set('relative','1')

#Flecha con clase Humano
ai = ET.SubElement(d, 'mxCell')
ai.set('id','18')
ai.set('parent','1')
ai.set('target','16')
ai.set('source','2')
ai.set('edge','1')
ai.set('style','edgeStyle=orthogonalEdgeStyle;rounded=0;orthogonalLoop=1;jettySize=auto;html=1;exitX=1;exitY=0.5;exitDx=0;exitDy=0;dashed=1;endArrow=classic;endFill=1;')
ai.set('value','Creador (P170)')
ai1 = ET.SubElement(ai, 'mxGeometry')
ai1.set('as','geometry')
ai1.set('relative','1')

#Flecha con clase Humano
ai = ET.SubElement(d, 'mxCell')
ai.set('id','19')
ai.set('parent','1')
ai.set('target','16')
ai.set('source','2')
ai.set('edge','1')
ai.set('style','edgeStyle=orthogonalEdgeStyle;rounded=0;orthogonalLoop=1;jettySize=auto;html=1;exitX=1;exitY=0.5;exitDx=0;exitDy=0;dashed=1;endArrow=classic;endFill=1;')
ai.set('value','Desarollador (P178)')
ai1 = ET.SubElement(ai, 'mxGeometry')
ai1.set('as','geometry')
ai1.set('relative','1')

#Flecha con clase Humano
ai = ET.SubElement(d, 'mxCell')
ai.set('id','20')
ai.set('parent','1')
ai.set('target','16')
ai.set('source','2')
ai.set('edge','1')
ai.set('style','edgeStyle=orthogonalEdgeStyle;rounded=0;orthogonalLoop=1;jettySize=auto;html=1;exitX=1;exitY=0.5;exitDx=0;exitDy=0;dashed=1;endArrow=classic;endFill=1;')
ai.set('value','Fabricante (P176)')
ai1 = ET.SubElement(ai, 'mxGeometry')
ai1.set('as','geometry')
ai1.set('relative','1')

#Flecha con clase Humano
ai = ET.SubElement(d, 'mxCell')
ai.set('id','21')
ai.set('parent','1')
ai.set('target','16')
ai.set('source','2')
ai.set('edge','1')
ai.set('style','edgeStyle=orthogonalEdgeStyle;rounded=0;orthogonalLoop=1;jettySize=auto;html=1;exitX=1;exitY=0.5;exitDx=0;exitDy=0;dashed=1;endArrow=classic;endFill=1;')
ai.set('value','Descubridor (P61)')
ai1 = ET.SubElement(ai, 'mxGeometry')
ai1.set('as','geometry')
ai1.set('relative','1')

# %%
ET.dump(a)
# Out:
# <mxfile agent="5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.75 Safari/537.36" etag="d2m_BCRs5NTD1uJDUOON" host="app.diagrams.net" modified="2020-11-05T11:56:57.085Z" type="device" version="13.9.1"><diagram id="E2t0QyFFZp_JITEdpmB3"><mxGraphModel arrows="1" connect="1" dx="21749" dy="18481" fold="1" grid="1" gridSize="10" guides="1" math="0" page="1" pageHeight="1169" pageScale="1" pageWidth="827" shadow="0" tooltips="1"><root><mxCell id="0" /><mxCell id="1" parent="0" /><mxCell id="2" parent="1" style="rounded=0;whiteSpace=wrap;html=1;fillColor=#fff2cc;strokeColor=#d6b656" value="Ordenador (Q68)" vertex="1"><mxGeometry as="geometry" height="27" width="212" x="-18500" y="-16200" /></mxCell><mxCell id="3" parent="1" style="rounded=0;whiteSpace=wrap;html=1" value="Pais (Q6250)" vertex="1"><mxGeometry as="geometry" height="27" width="212" x="-18800" y="-16800" /></mxCell><mxCell edge="1" id="4" parent="1" source="2" style="edgeStyle=orthogonal
# ...

# %%
tree = ET.ElementTree(a)
tree.write("output_ordenador.xml", encoding='utf-8', xml_declaration=True)
