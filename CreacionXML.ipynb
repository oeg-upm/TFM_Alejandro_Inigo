# %%
import xml.etree.ElementTree as ET

# %%
a=ET.Element('mxfile')
a.set('type','device')
a.set('etag','d2m_BCRs5NTD1uJDUOON')
a.set('version','13.9.1')
a.set('agent','5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.75 Safari/537.36')
a.set('modified','2020-11-05T11:56:57.085Z')
a.set('host','app.diagrams.net')

# %%
b = ET.SubElement(a, 'diagram')
b.set('id','E2t0QyFFZp_JITEdpmB3')

# %%
c = ET.SubElement(b, 'mxGraphModel')
c.set('shadow','0')
c.set('math','0')
c.set('pageHeight','1169')
c.set('pageWidth','827')
c.set('pageScale','1')
c.set('page','1')
c.set('fold','1')
c.set('arrows','1')
c.set('connect','1')
c.set('tooltips','1')
c.set('guides','1')
c.set('gridSize','10')
c.set('grid','1')
c.set('dy','18481')
c.set('dx','21749')

# %%
d = ET.SubElement(c, 'root')

# %%
e = ET.SubElement(d, 'mxCell')
e.set('id','0')
f = ET.SubElement(d, 'mxCell')
f.set('id','1')
f.set('parent','0')

#Caja con clase Comics
g = ET.SubElement(d, 'mxCell')
g.set('id','2')
g.set('parent','1')
g.set('style','rounded=0;whiteSpace=wrap;html=1;fillColor=#fff2cc;strokeColor=#d6b656')
g.set('vertex','1')
g.set('value','Comics (Q1004)')
g1 = ET.SubElement(g, 'mxGeometry')
g1.set('as','geometry')
g1.set('y','-16200')
g1.set('x','-18500')
g1.set('height','27')
g1.set('width','212')

#Caja con clase Region Geografica
h = ET.SubElement(d, 'mxCell')
h.set('id','3')
h.set('parent','1')
h.set('style','rounded=0;whiteSpace=wrap;html=1')
h.set('vertex','1')
h.set('value','Region Geografica(Q82794)')
h1 = ET.SubElement(h, 'mxGeometry')
h1.set('as','geometry')
h1.set('y','-16800')
h1.set('x','-20900')
h1.set('height','27')
h1.set('width','212')

#Caja con clase Objecto Geográfico
i = ET.SubElement(d, 'mxCell')
i.set('id','4')
i.set('parent','1')
i.set('style','rounded=0;whiteSpace=wrap;html=1')
i.set('vertex','1')
i.set('value','Objeto Geografico(Q618123)')
i1 = ET.SubElement(i, 'mxGeometry')
i1.set('as','geometry')
i1.set('y','-16800')
i1.set('x','-20650')
i1.set('height','27')
i1.set('width','212')

#Flecha Ubicacion narrativa 1
j = ET.SubElement(d, 'mxCell')
j.set('id','5')
j.set('parent','1')
j.set('target','3')
j.set('source','2')
j.set('edge','1')
j.set('style','edgeStyle=orthogonalEdgeStyle;rounded=0;orthogonalLoop=1;jettySize=auto;html=1;exitX=1;exitY=0.5;exitDx=0;exitDy=0;dashed=1;endArrow=classic;endFill=1;')
j1 = ET.SubElement(j, 'mxGeometry')
j1.set('as','geometry')
j1.set('relative','1')

#Flecha Ubicacion narrativa 2
k = ET.SubElement(d, 'mxCell')
k.set('id','6')
k.set('parent','1')
k.set('target','4')
k.set('source','2')
k.set('edge','1')
k.set('style','edgeStyle=orthogonalEdgeStyle;rounded=0;orthogonalLoop=1;jettySize=auto;html=1;exitX=1;exitY=0.5;exitDx=0;exitDy=0;dashed=1;endArrow=classic;endFill=1;')
k.set('value','Ubicacion narrativa(P840)')
k1 = ET.SubElement(k, 'mxGeometry')
k1.set('as','geometry')
k1.set('relative','1')

#Caja con clase Lengua
l = ET.SubElement(d, 'mxCell')
l.set('id','7')
l.set('parent','1')
l.set('style','rounded=0;whiteSpace=wrap;html=1')
l.set('vertex','1')
l.set('value','Lengua(Q17376908)')
l1 = ET.SubElement(l, 'mxGeometry')
l1.set('as','geometry')
l1.set('y','-16320')
l1.set('x','-21900')
l1.set('height','27')
l1.set('width','212')

#Flecha Idioma
k = ET.SubElement(d, 'mxCell')
k.set('id','8')
k.set('parent','1')
k.set('target','7')
k.set('source','2')
k.set('edge','1')
k.set('style','edgeStyle=orthogonalEdgeStyle;rounded=0;orthogonalLoop=1;jettySize=auto;html=1;exitX=1;exitY=0.5;exitDx=0;exitDy=0;dashed=1;endArrow=classic;endFill=1;')
k.set('value','Idioma(P407)')
k1 = ET.SubElement(k, 'mxGeometry')
k1.set('as','geometry')
k1.set('relative','1')

#Caja con clase Pais
l = ET.SubElement(d, 'mxCell')
l.set('id','9')
l.set('parent','1')
l.set('style','rounded=0;whiteSpace=wrap;html=1')
l.set('vertex','1')
l.set('value','Pais(Q6256)')
l1 = ET.SubElement(l, 'mxGeometry')
l1.set('as','geometry')
l1.set('y','-16400')
l1.set('x','-21700')
l1.set('height','27')
l1.set('width','212')

#Flecha Pais
m = ET.SubElement(d, 'mxCell')
m.set('id','10')
m.set('parent','1')
m.set('target','9')
m.set('source','2')
m.set('edge','1')
m.set('style','edgeStyle=orthogonalEdgeStyle;rounded=0;orthogonalLoop=1;jettySize=auto;html=1;exitX=1;exitY=0.5;exitDx=0;exitDy=0;dashed=1;endArrow=classic;endFill=1;')
m.set('value','Pais(P495)')
m1 = ET.SubElement(m, 'mxGeometry')
m1.set('as','geometry')
m1.set('relative','1')

#Caja con clase Personaje de Ficcion
n = ET.SubElement(d, 'mxCell')
n.set('id','11')
n.set('parent','1')
n.set('style','rounded=0;whiteSpace=wrap;html=1')
n.set('vertex','1')
n.set('value','Personaje de Ficcion(Q95074)')
n1 = ET.SubElement(n, 'mxGeometry')
n1.set('as','geometry')
n1.set('y','-16500')
n1.set('x','-21500')
n1.set('height','27')
n1.set('width','212')

#Flecha con clase Personaje de Ficcion
o = ET.SubElement(d, 'mxCell')
o.set('id','12')
o.set('parent','1')
o.set('target','11')
o.set('source','2')
o.set('edge','1')
o.set('style','edgeStyle=orthogonalEdgeStyle;rounded=0;orthogonalLoop=1;jettySize=auto;html=1;exitX=1;exitY=0.5;exitDx=0;exitDy=0;dashed=1;endArrow=classic;endFill=1;')
o.set('value','Personaje(P674)')
o1 = ET.SubElement(o, 'mxGeometry')
o1.set('as','geometry')
o1.set('relative','1')

#Caja con clase Publicador
p = ET.SubElement(d, 'mxCell')
p.set('id','13')
p.set('parent','1')
p.set('style','rounded=0;whiteSpace=wrap;html=1')
p.set('vertex','1')
p.set('value','Publicador (Q2085381)')
p1 = ET.SubElement(p, 'mxGeometry')
p1.set('as','geometry')
p1.set('y','-16600')
p1.set('x','-21300')
p1.set('height','27')
p1.set('width','212')

#Flecha con clase Publicador
q = ET.SubElement(d, 'mxCell')
q.set('id','14')
q.set('parent','1')
q.set('target','13')
q.set('source','2')
q.set('edge','1')
q.set('style','edgeStyle=orthogonalEdgeStyle;rounded=0;orthogonalLoop=1;jettySize=auto;html=1;exitX=1;exitY=0.5;exitDx=0;exitDy=0;dashed=1;endArrow=classic;endFill=1;')
q.set('value','Publicador(P123)')
q1 = ET.SubElement(q, 'mxGeometry')
q1.set('as','geometry')
q1.set('relative','1')

#Caja con clase Genero
r = ET.SubElement(d, 'mxCell')
r.set('id','15')
r.set('parent','1')
r.set('style','rounded=0;whiteSpace=wrap;html=1')
r.set('vertex','1')
r.set('value','Genero (Q483394)')
r1 = ET.SubElement(r, 'mxGeometry')
r1.set('as','geometry')
r1.set('y','-16700')
r1.set('x','-21100')
r1.set('height','27')
r1.set('width','212')

#Flecha con clase Genero
s = ET.SubElement(d, 'mxCell')
s.set('id','16')
s.set('parent','1')
s.set('target','15')
s.set('source','2')
s.set('edge','1')
s.set('style','edgeStyle=orthogonalEdgeStyle;rounded=0;orthogonalLoop=1;jettySize=auto;html=1;exitX=1;exitY=0.5;exitDx=0;exitDy=0;dashed=1;endArrow=classic;endFill=1;')
s.set('value','Genero(P136)')
s1 = ET.SubElement(s, 'mxGeometry')
s1.set('as','geometry')
s1.set('relative','1')

#Caja con clase Nombre de Pila
t = ET.SubElement(d, 'mxCell')
t.set('id','17')
t.set('parent','1')
t.set('style','rounded=0;whiteSpace=wrap;html=1')
t.set('vertex','1')
t.set('value','Nombre de pila (Q202444)')
t1 = ET.SubElement(t, 'mxGeometry')
t1.set('as','geometry')
t1.set('y','-16270')
t1.set('x','-22100')
t1.set('height','27')
t1.set('width','212')

#Flecha con clase Nombre de Pila
u = ET.SubElement(d, 'mxCell')
u.set('id','18')
u.set('parent','1')
u.set('target','17')
u.set('source','2')
u.set('edge','1')
u.set('style','edgeStyle=orthogonalEdgeStyle;rounded=0;orthogonalLoop=1;jettySize=auto;html=1;exitX=1;exitY=0.5;exitDx=0;exitDy=0;dashed=1;endArrow=classic;endFill=1;')
u.set('value','Nombre de Pila (P735)')
u1 = ET.SubElement(u, 'mxGeometry')
u1.set('as','geometry')
u1.set('relative','1')

#Caja con clase Version, edicion o traduccion
v = ET.SubElement(d, 'mxCell')
v.set('id','19')
v.set('parent','1')
v.set('style','rounded=0;whiteSpace=wrap;html=1')
v.set('vertex','1')
v.set('value','Version, edicion o traduccion(Q3331189)')
v1 = ET.SubElement(v, 'mxGeometry')
v1.set('as','geometry')
v1.set('y','-16900')
v1.set('x','-20450')
v1.set('height','27')
v1.set('width','212')

#Flecha con clase Version, edicion o traduccion
w = ET.SubElement(d, 'mxCell')
w.set('id','20')
w.set('parent','1')
w.set('target','19')
w.set('source','2')
w.set('edge','1')
w.set('style','edgeStyle=orthogonalEdgeStyle;rounded=0;orthogonalLoop=1;jettySize=auto;html=1;exitX=1;exitY=0.5;exitDx=0;exitDy=0;dashed=1;endArrow=classic;endFill=1;')
w.set('value','Edicion o traduccion(P747)')
w1 = ET.SubElement(w, 'mxGeometry')
w1.set('as','geometry')
w1.set('relative','1')

#Caja con clase Distincion
x = ET.SubElement(d, 'mxCell')
x.set('id','21')
x.set('parent','1')
x.set('style','rounded=0;whiteSpace=wrap;html=1')
x.set('vertex','1')
x.set('value','Distincion(Q618779)')
x1 = ET.SubElement(x, 'mxGeometry')
x1.set('as','geometry')
x1.set('y','-17000')
x1.set('x','-20250')
x1.set('height','27')
x1.set('width','212')

#Caja con clase Clase de Premio
y = ET.SubElement(d, 'mxCell')
y.set('id','22')
y.set('parent','1')
y.set('style','rounded=0;whiteSpace=wrap;html=1')
y.set('vertex','1')
y.set('value','Clase de Premio (Q38033430)')
y1 = ET.SubElement(y, 'mxGeometry')
y1.set('as','geometry')
y1.set('y','-17000')
y1.set('x','-19950')
y1.set('height','27')
y1.set('width','212')

#Flecha Ubicacion Premio Recibido
z = ET.SubElement(d, 'mxCell')
z.set('id','23')
z.set('parent','1')
z.set('target','21')
z.set('source','2')
z.set('edge','1')
z.set('style','edgeStyle=orthogonalEdgeStyle;rounded=0;orthogonalLoop=1;jettySize=auto;html=1;exitX=1;exitY=0.5;exitDx=0;exitDy=0;dashed=1;endArrow=classic;endFill=1;')
z1 = ET.SubElement(z, 'mxGeometry')
z1.set('as','geometry')
z1.set('relative','1')

#Flecha Ubicacion Premio recibido
aa = ET.SubElement(d, 'mxCell')
aa.set('id','24')
aa.set('parent','1')
aa.set('target','22')
aa.set('source','2')
aa.set('edge','1')
aa.set('style','edgeStyle=orthogonalEdgeStyle;rounded=0;orthogonalLoop=1;jettySize=auto;html=1;exitX=1;exitY=0.5;exitDx=0;exitDy=0;dashed=1;endArrow=classic;endFill=1;')
aa.set('value','Premio recibido(P166)')
aa1 = ET.SubElement(aa, 'mxGeometry')
aa1.set('as','geometry')
aa1.set('relative','1')

#Caja con clase Estado soberano
ab = ET.SubElement(d, 'mxCell')
ab.set('id','25')
ab.set('parent','1')
ab.set('style','rounded=0;whiteSpace=wrap;html=1')
ab.set('vertex','1')
ab.set('value','Estado soberano(Q3624078)')
ab1 = ET.SubElement(ab, 'mxGeometry')
ab1.set('as','geometry')
ab1.set('y','-17100')
ab1.set('x','-19750')
ab1.set('height','27')
ab1.set('width','212')

#Caja con clase Pais
ac = ET.SubElement(d, 'mxCell')
ac.set('id','26')
ac.set('parent','1')
ac.set('style','rounded=0;whiteSpace=wrap;html=1')
ac.set('vertex','1')
ac.set('value','Pais (Q6256)')
ac1 = ET.SubElement(ac, 'mxGeometry')
ac1.set('as','geometry')
ac1.set('y','-17100')
ac1.set('x','-19500')
ac1.set('height','27')
ac1.set('width','212')

#Caja con clase Federacion
ad = ET.SubElement(d, 'mxCell')
ad.set('id','27')
ad.set('parent','1')
ad.set('style','rounded=0;whiteSpace=wrap;html=1')
ad.set('vertex','1')
ad.set('value','Federacion (Q182547)')
ad1 = ET.SubElement(ad, 'mxGeometry')
ad1.set('as','geometry')
ad1.set('y','-17100')
ad1.set('x','-19250')
ad1.set('height','27')
ad1.set('width','212')

#Flecha Estado soberano
ae = ET.SubElement(d, 'mxCell')
ae.set('id','28')
ae.set('parent','1')
ae.set('target','25')
ae.set('source','2')
ae.set('edge','1')
ae.set('style','edgeStyle=orthogonalEdgeStyle;rounded=0;orthogonalLoop=1;jettySize=auto;html=1;exitX=1;exitY=0.5;exitDx=0;exitDy=0;dashed=1;endArrow=classic;endFill=1;')
ae1 = ET.SubElement(ae, 'mxGeometry')
ae1.set('as','geometry')
ae1.set('relative','1')

#Flecha Pais
af = ET.SubElement(d, 'mxCell')
af.set('id','29')
af.set('parent','1')
af.set('target','26')
af.set('source','2')
af.set('edge','1')
af.set('style','edgeStyle=orthogonalEdgeStyle;rounded=0;orthogonalLoop=1;jettySize=auto;html=1;exitX=1;exitY=0.5;exitDx=0;exitDy=0;dashed=1;endArrow=classic;endFill=1;')
af1 = ET.SubElement(af, 'mxGeometry')
af1.set('as','geometry')
af1.set('relative','1')

#Flecha Federacion
ag = ET.SubElement(d, 'mxCell')
ag.set('id','30')
ag.set('parent','1')
ag.set('target','27')
ag.set('source','2')
ag.set('edge','1')
ag.set('style','edgeStyle=orthogonalEdgeStyle;rounded=0;orthogonalLoop=1;jettySize=auto;html=1;exitX=1;exitY=0.5;exitDx=0;exitDy=0;dashed=1;endArrow=classic;endFill=1;')
ag.set('value','Pais (P17)')
ag1 = ET.SubElement(ag, 'mxGeometry')
ag1.set('as','geometry')
ag1.set('relative','1')

#Caja con clase Humano
ah = ET.SubElement(d, 'mxCell')
ah.set('id','31')
ah.set('parent','1')
ah.set('style','rounded=0;whiteSpace=wrap;html=1')
ah.set('vertex','1')
ah.set('value','Humano (Q5)')
ah1 = ET.SubElement(ah, 'mxGeometry')
ah1.set('as','geometry')
ah1.set('y','-17200')
ah1.set('x','-19050')
ah1.set('height','27')
ah1.set('width','212')

#Flecha con clase Humano
ai = ET.SubElement(d, 'mxCell')
ai.set('id','32')
ai.set('parent','1')
ai.set('target','31')
ai.set('source','2')
ai.set('edge','1')
ai.set('style','edgeStyle=orthogonalEdgeStyle;rounded=0;orthogonalLoop=1;jettySize=auto;html=1;exitX=1;exitY=0.5;exitDx=0;exitDy=0;dashed=1;endArrow=classic;endFill=1;')
ai.set('value','Inspirado por(P941), Colorista(P6338), Autor(P50), Ilustrador(P110), Creador(P170)')
ai1 = ET.SubElement(ai, 'mxGeometry')
ai1.set('as','geometry')
ai1.set('relative','1')

#Caja con los dataType Strings
aj = ET.SubElement(d,'mxCell')
aj.set('id','33')
aj.set('parent','1')
aj.set('style','rounded=0;whiteSpace=wrap;html=1;align=left;dashed=1')
aj.set('vertex','1')
aj.set('value','Datatypes String')
aj1=ET.SubElement(aj,'mxGeometry')
aj1.set('as','geometry')
aj1.set('y','-16173')
aj1.set('x','-18500')
aj1.set('height','85')
aj1.set('width','212')

# %%
ET.dump(a)
# Out:
# <mxfile agent="5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.75 Safari/537.36" etag="d2m_BCRs5NTD1uJDUOON" host="app.diagrams.net" modified="2020-11-05T11:56:57.085Z" type="device" version="13.9.1"><diagram id="E2t0QyFFZp_JITEdpmB3"><mxGraphModel arrows="1" connect="1" dx="21749" dy="18481" fold="1" grid="1" gridSize="10" guides="1" math="0" page="1" pageHeight="1169" pageScale="1" pageWidth="827" shadow="0" tooltips="1"><root><mxCell id="0" /><mxCell id="1" parent="0" /><mxCell id="2" parent="1" style="rounded=0;whiteSpace=wrap;html=1;fillColor=#fff2cc;strokeColor=#d6b656" value="Comics (Q1004)" vertex="1"><mxGeometry as="geometry" height="27" width="212" x="-18500" y="-16200" /></mxCell><mxCell id="3" parent="1" style="rounded=0;whiteSpace=wrap;html=1" value="Region Geografica(Q82794)" vertex="1"><mxGeometry as="geometry" height="27" width="212" x="-20900" y="-16800" /></mxCell><mxCell id="4" parent="1" style="rounded=0;whiteSpace=wrap;ht
# ...

# %%
tree = ET.ElementTree(a)
tree.write("output.xml", encoding='utf-8', xml_declaration=True)
